# %% [markdown]
# !wget --no-check-certificate https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pengembangan_academy/Chessman-image-dataset.zip -O /tmp/Chessman-image-dataset.zip

# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2021-08-11 07:03:48--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2021-08-11 07:03:48--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   161MB/s    in 0.4s
#
# 2021-08-11 07:03:49 (161 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Queen', 'Bishop', 'Rook', 'Pawn', 'King', 'Knight']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=1)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 37s 574ms/step - loss: 1.8515 - accuracy: 0.1743 - val_loss: 1.7842 - val_accuracy: 0.1923
# Epoch 2/50
# 63/63 [==============================] - 35s 561ms/step - loss: 1.7851 - accuracy: 0.1884 - val_loss: 1.7784 - val_accuracy: 0.1923
# Epoch 3/50
# 63/63 [==============================] - 35s 562ms/step - loss: 1.7592 - accuracy: 0.2164 - val_loss: 1.7824 - val_accuracy: 0.2308
# Epoch 4/50
# 63/63 [==============================] - 36s 557ms/step - loss: 1.7356 - accuracy: 0.2485 - val_loss: 1.7632 - val_accuracy: 0.2115
# Epoch 5/50
# 63/63 [==============================] - 35s 559ms/step - loss: 1.6812 - accuracy: 0.2806 - val_loss: 1.7325 - val_accuracy: 0.2308
# Epoch 6/50
# 63/63 [==============================] - 36s 567ms/step - loss: 1.6702 - accuracy: 0.3026 - val_loss: 1.6817 - val_accuracy: 0.3077
# Epoch 7/50
# 63/63 [==============================] - 36s 567ms/step - loss: 1.6257 - accuracy: 0.3347 - val_loss: 1.6652 - val_accuracy: 0.2692
# Epoch 8/50
# 63/63 [==============================] - 35s 556ms/step - loss: 1.5350 - accuracy: 0.3928 - val_loss: 1.6495 - val_accuracy: 0.3269
# Epoch 9/50
# 63/63 [==============================] - 36s 566ms/step - loss: 1.5446 - accuracy: 0.3607 - val_loss: 1.7282 - val_accuracy: 0.2500
# Epoch 10/50
# 63/63 [==============================] - 35s 559ms/step - loss: 1.5019 - accuracy: 0.4148 - val_loss: 1.7099 - val_accuracy: 0.2692
# Epoch 11/50
# 63/63 [==============================] - 35s 559ms/step - loss: 1.4370 - accuracy: 0.4409 - val_loss: 1.5116 - val_accuracy: 0.3654
# Epoch 12/50
# 63/63 [==============================] - 35s 561ms/step - loss: 1.3803 - accuracy: 0.4349 - val_loss: 1.5959 - val_accuracy: 0.3269
# Epoch 13/50
# 63/63 [==============================] - 35s 557ms/step - loss: 1.3050 - accuracy: 0.4770 - val_loss: 1.5932 - val_accuracy: 0.3462
# Epoch 14/50
# 63/63 [==============================] - 36s 562ms/step - loss: 1.3601 - accuracy: 0.4629 - val_loss: 1.6453 - val_accuracy: 0.3077
# Epoch 15/50
# 63/63 [==============================] - 36s 570ms/step - loss: 1.2562 - accuracy: 0.5150 - val_loss: 1.6436 - val_accuracy: 0.3269
# Epoch 16/50
# 63/63 [==============================] - 36s 564ms/step - loss: 1.2399 - accuracy: 0.5190 - val_loss: 1.6343 - val_accuracy: 0.3077
# Epoch 17/50
# 63/63 [==============================] - 36s 575ms/step - loss: 1.1572 - accuracy: 0.5631 - val_loss: 1.5842 - val_accuracy: 0.3462
# Epoch 18/50
# 63/63 [==============================] - 36s 564ms/step - loss: 1.2340 - accuracy: 0.5291 - val_loss: 1.5577 - val_accuracy: 0.4231
# Epoch 19/50
# 63/63 [==============================] - 35s 557ms/step - loss: 1.1498 - accuracy: 0.5431 - val_loss: 1.5547 - val_accuracy: 0.3462
# Epoch 20/50
# 63/63 [==============================] - 35s 557ms/step - loss: 1.1029 - accuracy: 0.5912 - val_loss: 1.5408 - val_accuracy: 0.3269
# Epoch 21/50
# 63/63 [==============================] - 35s 558ms/step - loss: 1.1369 - accuracy: 0.5551 - val_loss: 1.5133 - val_accuracy: 0.4615
# Epoch 22/50
# 63/63 [==============================] - 36s 564ms/step - loss: 0.9907 - accuracy: 0.6152 - val_loss: 1.5818 - val_accuracy: 0.4231
# Epoch 23/50
# 63/63 [==============================] - 35s 557ms/step - loss: 1.0539 - accuracy: 0.5892 - val_loss: 1.5186 - val_accuracy: 0.4231
# Epoch 24/50
# 63/63 [==============================] - 35s 552ms/step - loss: 0.9804 - accuracy: 0.6132 - val_loss: 1.4745 - val_accuracy: 0.4423
# Epoch 25/50
# 63/63 [==============================] - 35s 559ms/step - loss: 0.9385 - accuracy: 0.6493 - val_loss: 1.7199 - val_accuracy: 0.4423
# Epoch 26/50
# 63/63 [==============================] - 35s 560ms/step - loss: 0.9106 - accuracy: 0.6613 - val_loss: 1.5604 - val_accuracy: 0.4038
# Epoch 27/50
# 63/63 [==============================] - 35s 556ms/step - loss: 0.8627 - accuracy: 0.6613 - val_loss: 1.6774 - val_accuracy: 0.3269
# Epoch 28/50
# 63/63 [==============================] - 35s 559ms/step - loss: 0.8432 - accuracy: 0.6894 - val_loss: 1.7293 - val_accuracy: 0.2885
# Epoch 29/50
# 63/63 [==============================] - 35s 556ms/step - loss: 0.8075 - accuracy: 0.7074 - val_loss: 1.4676 - val_accuracy: 0.3654
# Epoch 30/50
# 63/63 [==============================] - 35s 554ms/step - loss: 0.7880 - accuracy: 0.7154 - val_loss: 1.5466 - val_accuracy: 0.4038
# Epoch 31/50
# 63/63 [==============================] - 35s 558ms/step - loss: 0.7558 - accuracy: 0.7134 - val_loss: 1.7216 - val_accuracy: 0.3077
# Epoch 32/50
# 63/63 [==============================] - 35s 548ms/step - loss: 0.7943 - accuracy: 0.7234 - val_loss: 1.6475 - val_accuracy: 0.4423
# Epoch 33/50
# 63/63 [==============================] - 35s 554ms/step - loss: 0.7446 - accuracy: 0.7154 - val_loss: 1.6667 - val_accuracy: 0.4615
# Epoch 34/50
# 63/63 [==============================] - 35s 559ms/step - loss: 0.6894 - accuracy: 0.7315 - val_loss: 1.7448 - val_accuracy: 0.3846
# Epoch 35/50
# 63/63 [==============================] - 35s 556ms/step - loss: 0.7145 - accuracy: 0.7295 - val_loss: 1.9196 - val_accuracy: 0.3462
# Epoch 36/50
# 63/63 [==============================] - 35s 554ms/step - loss: 0.6764 - accuracy: 0.7515 - val_loss: 1.6861 - val_accuracy: 0.4038
# Epoch 37/50
# 63/63 [==============================] - 35s 554ms/step - loss: 0.6235 - accuracy: 0.7735 - val_loss: 1.6635 - val_accuracy: 0.4615
# Epoch 38/50
# 63/63 [==============================] - 35s 552ms/step - loss: 0.6353 - accuracy: 0.7776 - val_loss: 1.4665 - val_accuracy: 0.4231
# Epoch 39/50
# 63/63 [==============================] - 35s 551ms/step - loss: 0.6049 - accuracy: 0.7816 - val_loss: 1.9182 - val_accuracy: 0.4038
# Epoch 40/50
# 63/63 [==============================] - 35s 557ms/step - loss: 0.6102 - accuracy: 0.7776 - val_loss: 1.7965 - val_accuracy: 0.3462
# Epoch 41/50
# 63/63 [==============================] - 36s 571ms/step - loss: 0.5273 - accuracy: 0.8156 - val_loss: 1.9692 - val_accuracy: 0.4038
# Epoch 42/50
# 63/63 [==============================] - 35s 557ms/step - loss: 0.5815 - accuracy: 0.7936 - val_loss: 1.6340 - val_accuracy: 0.5192
# Epoch 43/50
# 63/63 [==============================] - 35s 555ms/step - loss: 0.4908 - accuracy: 0.8156 - val_loss: 1.7691 - val_accuracy: 0.4423
# Epoch 44/50
# 63/63 [==============================] - 35s 552ms/step - loss: 0.5622 - accuracy: 0.7956 - val_loss: 1.4102 - val_accuracy: 0.4423
# Epoch 45/50
# 63/63 [==============================] - 35s 552ms/step - loss: 0.5017 - accuracy: 0.8076 - val_loss: 1.6393 - val_accuracy: 0.4808
# Epoch 46/50
# 63/63 [==============================] - 35s 555ms/step - loss: 0.5008 - accuracy: 0.8236 - val_loss: 1.7193 - val_accuracy: 0.4038
# Epoch 47/50
# 63/63 [==============================] - 35s 553ms/step - loss: 0.5255 - accuracy: 0.8357 - val_loss: 1.9082 - val_accuracy: 0.3462
# Epoch 48/50
# 63/63 [==============================] - 35s 552ms/step - loss: 0.4415 - accuracy: 0.8357 - val_loss: 1.7466 - val_accuracy: 0.3462
# Epoch 49/50
# 63/63 [==============================] - 35s 550ms/step - loss: 0.4323 - accuracy: 0.8397 - val_loss: 1.7797 - val_accuracy: 0.3462
# Epoch 50/50
# 63/63 [==============================] - 35s 559ms/step - loss: 0.4103 - accuracy: 0.8577 - val_loss: 1.7821 - val_accuracy: 0.5000

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
